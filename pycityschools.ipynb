# %%
import os
import csv
import pandas as pd

# %%
schools = os.path.join("pycityschools", "schools_complete.csv")
students = os.path.join("pycityschools", "students_complete.csv")

schools_df = pd.read_csv(schools)
students_df = pd.read_csv(students)

# %%
schools_df.head()
# Out:
#    School ID            school_name      type  size   budget
# 0          0      Huang High School  District  2917  1910635
# 1          1   Figueroa High School  District  2949  1884411
# 2          2    Shelton High School   Charter  1761  1056600
# 3          3  Hernandez High School  District  4635  3022020
# 4          4    Griffin High School   Charter  1468   917500

# %%
students_df.head()
# Out:
#    Student ID       student_name gender grade        school_name  \
# 0           0       Paul Bradley      M   9th  Huang High School
# 1           1       Victor Smith      M  12th  Huang High School
# 2           2    Kevin Rodriguez      M  12th  Huang High School
# 3           3  Dr. Richard Scott      M  12th  Huang High School
# 4           4         Bonnie Ray      F   9th  Huang High School
#
#    reading_score  math_score
# 0             66          79
# 1             94          61
# 2             90          60
# 3             67          58
# 4             97          84

# %%
# Total Schools
total_schools = schools_df["School ID"].nunique()
total_schools
# Out:
# 15

# %%
# Total Students
total_students = students_df["Student ID"].nunique()
total_students

# student_name does not work because there are several students with the same name. ID separates them all.
# Out:
# 39170

# %%
# Total Budget
total_budget = schools_df["budget"].sum()
total_budget
# Out:
# 24649428

# %%
# Average Math Score
avg_math_score = round(students_df["math_score"].mean(),2)
avg_math_score
# Out:
# 78.99

# %%
# Average Reading Score
avg_reading_score = round(students_df["reading_score"].mean(),2)
avg_reading_score
# Out:
# 81.88

# %%
# % Passing Math; assuming passing rate is 70%
pass_math = students_df[students_df["math_score"] >69].count()["student_name"]
percent_pass_math = round((pass_math/total_students)*100,2)
percent_pass_math
# Out:
# 74.98

# %%
# % Passing Reading; assuming passing rate is 70%
pass_reading = students_df[students_df["reading_score"] >69].count()["student_name"]
percent_pass_reading = round((pass_reading/total_students)*100,2)
percent_pass_reading

# originally went with 60%. Passing numbers were perfect. upped to 75% and applied same logic to math.
# eventually realized with the example provided in GitLab that the target pass score was 70%
# Out:
# 85.81

# %%
# % Overall Passing
overall_passing = round((students_df[(students_df['math_score'] >69) & (students_df['reading_score'] >69)]['student_name'].count()/total_students)*100,2)
overall_passing
# Out:
# 65.17

# %%
# DISTRICT SUMMARY TABLE
district_summary = pd.DataFrame({"Total Schools":[total_schools],
                      "Total Students":[total_students],
                      "Total Budget":[total_budget],
                      "Average Math Score":[avg_math_score],
                      'Average Reading Score':[avg_reading_score],
                      "% Passing Math":[percent_pass_math],
                      "% Passing Reading":[percent_pass_reading],
                      "% Overall Passing rate":[overall_passing]})

district_summary
# Out:
#    Total Schools  Total Students  Total Budget  Average Math Score  \
# 0             15           39170      24649428               78.99
#
#    Average Reading Score  % Passing Math  % Passing Reading  \
# 0                  81.88           74.98              85.81
#
#    % Overall Passing rate
# 0                   65.17

# %%
# School Type
school_type = schools_df.set_index(["school_name"])["type"]
school_type
# Out:
# school_name
# Huang High School        District
# Figueroa High School     District
# Shelton High School       Charter
# Hernandez High School    District
# Griffin High School       Charter
# Wilson High School        Charter
# Cabrera High School       Charter
# Bailey High School       District
# Holden High School        Charter
# Pena High School          Charter
# Wright High School        Charter
# Rodriguez High School    District
# Johnson High School      District
# Ford High School         District
# Thomas High School        Charter
# Name: type, dtype: object

# %%
# Create a combined dataframe
merge_df = pd.merge(schools_df, students_df, on="school_name")
merge_df.head()
# Out:
#    School ID        school_name      type  size   budget  Student ID  \
# 0          0  Huang High School  District  2917  1910635           0
# 1          0  Huang High School  District  2917  1910635           1
# 2          0  Huang High School  District  2917  1910635           2
# 3          0  Huang High School  District  2917  1910635           3
# 4          0  Huang High School  District  2917  1910635           4
#
#         student_name gender grade  reading_score  math_score
# 0       Paul Bradley      M   9th             66          79
# 1       Victor Smith      M  12th             94          61
# 2    Kevin Rodriguez      M  12th             90          60
# 3  Dr. Richard Scott      M  12th             67          58
# 4         Bonnie Ray      F   9th             97          84

# %%
# Total Students in each school
students_per_school = school_df['school_name'].value_counts()
students_per_school
# Out:
# Bailey High School       4976
# Johnson High School      4761
# Hernandez High School    4635
# Rodriguez High School    3999
# Figueroa High School     2949
# Huang High School        2917
# Ford High School         2739
# Wilson High School       2283
# Cabrera High School      1858
# Wright High School       1800
# Shelton High School      1761
# Thomas High School       1635
# Griffin High School      1468
# Pena High School          962
# Holden High School        427
# Name: school_name, dtype: int64

# %%
# School Budgets
school_budgets = merge_df.groupby(["school_name"]).mean()["budget"]
school_budgets
# Out:
# school_name
# Bailey High School       3124928.0
# Cabrera High School      1081356.0
# Figueroa High School     1884411.0
# Ford High School         1763916.0
# Griffin High School       917500.0
# Hernandez High School    3022020.0
# Holden High School        248087.0
# Huang High School        1910635.0
# Johnson High School      3094650.0
# Pena High School          585858.0
# Rodriguez High School    2547363.0
# Shelton High School      1056600.0
# Thomas High School       1043130.0
# Wilson High School       1319574.0
# Wright High School       1049400.0
# Name: budget, dtype: float64

# %%
# Per Student Budget
student_budget = school_budgets/students_per_school
student_budget
# Out:
# Bailey High School       628.0
# Cabrera High School      582.0
# Figueroa High School     639.0
# Ford High School         644.0
# Griffin High School      625.0
# Hernandez High School    652.0
# Holden High School       581.0
# Huang High School        655.0
# Johnson High School      650.0
# Pena High School         609.0
# Rodriguez High School    637.0
# Shelton High School      600.0
# Thomas High School       638.0
# Wilson High School       578.0
# Wright High School       583.0
# dtype: float64

# %%
# Average Math Score per school
avg_math_scores = round(merge_df.groupby(["school_name"]).mean()["math_score"],2)
avg_math_scores
# Out:
# school_name
# Bailey High School       77.05
# Cabrera High School      83.06
# Figueroa High School     76.71
# Ford High School         77.10
# Griffin High School      83.35
# Hernandez High School    77.29
# Holden High School       83.80
# Huang High School        76.63
# Johnson High School      77.07
# Pena High School         83.84
# Rodriguez High School    76.84
# Shelton High School      83.36
# Thomas High School       83.42
# Wilson High School       83.27
# Wright High School       83.68
# Name: math_score, dtype: float64

# %%
# Average Reading Score per school
avg_reading_scores = round(merge_df.groupby(["school_name"]).mean()["reading_score"],2)
avg_reading_scores
# Out:
# school_name
# Bailey High School       81.03
# Cabrera High School      83.98
# Figueroa High School     81.16
# Ford High School         80.75
# Griffin High School      83.82
# Hernandez High School    80.93
# Holden High School       83.81
# Huang High School        81.18
# Johnson High School      80.97
# Pena High School         84.04
# Rodriguez High School    80.74
# Shelton High School      83.73
# Thomas High School       83.85
# Wilson High School       83.99
# Wright High School       83.96
# Name: reading_score, dtype: float64

# %%
# % passing math per school
students_pass_math = merge_df[(merge_df["math_score"]>69)]
students_pass_math_per_school = students_pass_math.groupby(["school_name"]).count()["student_name"]
percent_pass_math_schools = round((students_pass_math_per_school/students_per_school)*100,2)
percent_pass_math_schools
# Out:
# Bailey High School       66.68
# Cabrera High School      94.13
# Figueroa High School     65.99
# Ford High School         68.31
# Griffin High School      93.39
# Hernandez High School    66.75
# Holden High School       92.51
# Huang High School        65.68
# Johnson High School      66.06
# Pena High School         94.59
# Rodriguez High School    66.37
# Shelton High School      93.87
# Thomas High School       93.27
# Wilson High School       93.87
# Wright High School       93.33
# dtype: float64

# %%
# % passing reading per school
students_pass_read = merge_df[(merge_df["reading_score"]>69)]
students_pass_read_per_school = students_pass_read.groupby(["school_name"]).count()["student_name"]
percent_pass_read_schools = round((students_pass_read_per_school/students_per_school)*100,2)
percent_pass_read_schools
# Out:
# Bailey High School       81.93
# Cabrera High School      97.04
# Figueroa High School     80.74
# Ford High School         79.30
# Griffin High School      97.14
# Hernandez High School    80.86
# Holden High School       96.25
# Huang High School        81.32
# Johnson High School      81.22
# Pena High School         95.95
# Rodriguez High School    80.22
# Shelton High School      95.85
# Thomas High School       97.31
# Wilson High School       96.54
# Wright High School       96.61
# dtype: float64

# %%
# % overall passing rate per school
overall_pass = round((merge_df[(merge_df['reading_score'] >69) & (merge_df['math_score'] >69)].groupby('school_name')['Student ID'].count()/students_per_school)*100,2)
overall_pass
# Out:
# Bailey High School       54.64
# Cabrera High School      91.33
# Figueroa High School     53.20
# Ford High School         54.29
# Griffin High School      90.60
# Hernandez High School    53.53
# Holden High School       89.23
# Huang High School        53.51
# Johnson High School      53.54
# Pena High School         90.54
# Rodriguez High School    52.99
# Shelton High School      89.89
# Thomas High School       90.95
# Wilson High School       90.58
# Wright High School       90.33
# dtype: float64

# %%
# SCHOOL SUMMARY TABLE
school_summary = pd.DataFrame({"School Type":school_type,
                      "Total Students":students_per_school,
                      "Total Budget":school_budgets,
                      "Student Budget":student_budget,
                      "Average Math Score":avg_math_scores,
                      'Average Reading Score':avg_reading_scores,
                      "% Passing Math":percent_pass_math_schools,
                      "% Passing Reading":percent_pass_read_schools,
                      "% Overall Passing rate":overall_pass})

school_summary
# Out:
#                       School Type  Total Students  Total Budget  \
# Bailey High School       District            4976     3124928.0
# Cabrera High School       Charter            1858     1081356.0
# Figueroa High School     District            2949     1884411.0
# Ford High School         District            2739     1763916.0
# Griffin High School       Charter            1468      917500.0
# Hernandez High School    District            4635     3022020.0
# Holden High School        Charter             427      248087.0
# Huang High School        District            2917     1910635.0
# Johnson High School      District            4761     3094650.0
# Pena High School          Charter             962      585858.0
# Rodriguez High School    District            3999     2547363.0
# Shelton High School       Charter            1761     1056600.0
# Thomas High School        Charter            1635     1043130.0
# Wilson High School        Charter            2283     1319574.0
# ...

# %%
# Top Performing Schools
top_performers = school_summary.sort_values("% Overall Passing rate", ascending = False)
top_performers.head()
# Out:
#                     School Type  Total Students  Total Budget  Student Budget  \
# Cabrera High School     Charter            1858     1081356.0           582.0
# Thomas High School      Charter            1635     1043130.0           638.0
# Griffin High School     Charter            1468      917500.0           625.0
# Wilson High School      Charter            2283     1319574.0           578.0
# Pena High School        Charter             962      585858.0           609.0
#
#                      Average Math Score  Average Reading Score  \
# Cabrera High School               83.06                  83.98
# Thomas High School                83.42                  83.85
# Griffin High School               83.35                  83.82
# Wilson High School                83.27                  83.99
# Pena High School                  83.84                  84.04
#
#                      % Passing Math  % Passing Reading  % Overall Passing rate
# ...

# %%
# Bottom Performing Schools
bottom_performers = school_summary.sort_values("% Overall Passing rate", ascending = True)
bottom_performers.head()
# Out:
#                       School Type  Total Students  Total Budget  \
# Rodriguez High School    District            3999     2547363.0
# Figueroa High School     District            2949     1884411.0
# Huang High School        District            2917     1910635.0
# Hernandez High School    District            4635     3022020.0
# Johnson High School      District            4761     3094650.0
#
#                        Student Budget  Average Math Score  \
# Rodriguez High School           637.0               76.84
# Figueroa High School            639.0               76.71
# Huang High School               655.0               76.63
# Hernandez High School           652.0               77.29
# Johnson High School             650.0               77.07
#
#                        Average Reading Score  % Passing Math  \
# Rodriguez High School                  80.74           66.37
# Figueroa High School                   81.16           65.99
# ...

# %%
# Math Scores by Grade
freshman_math = students_df.loc[students_df['grade'] == "9th"].groupby('school_name')["math_score"].mean()
sophomore_math = students_df.loc[students_df['grade'] == "10th"].groupby('school_name')["math_score"].mean()
junior_math = students_df.loc[students_df['grade'] == "11th"].groupby('school_name')["math_score"].mean()
senior_math = students_df.loc[students_df['grade'] == "12th"].groupby('school_name')["math_score"].mean()

math_scores_grade = pd.DataFrame({"9th": freshman_math,
                                  "10th": sophomore_math,
                                  "11th": junior_math,
                                  "12th": senior_math
})

math_scores_grade = math_scores_grade[['9th', '10th', '11th', '12th']]
math_scores_grade.index.name = "School"

math_scores_grade
# Out:
#                              9th       10th       11th       12th
# School
# Bailey High School     77.083676  76.996772  77.515588  76.492218
# Cabrera High School    83.094697  83.154506  82.765560  83.277487
# Figueroa High School   76.403037  76.539974  76.884344  77.151369
# Ford High School       77.361345  77.672316  76.918058  76.179963
# Griffin High School    82.044010  84.229064  83.842105  83.356164
# Hernandez High School  77.438495  77.337408  77.136029  77.186567
# Holden High School     83.787402  83.429825  85.000000  82.855422
# Huang High School      77.027251  75.908735  76.446602  77.225641
# Johnson High School    77.187857  76.691117  77.491653  76.863248
# Pena High School       83.625455  83.372000  84.328125  84.121547
# Rodriguez High School  76.859966  76.612500  76.395626  77.690748
# Shelton High School    83.420755  82.917411  83.383495  83.778976
# Thomas High School     83.590022  83.087886  83.498795  83.497041
# ...

# %%
# Reading Scores by Grade
freshman_reading = students_df.loc[students_df['grade'] == "9th"].groupby('school_name')["reading_score"].mean()
sophomore_reading = students_df.loc[students_df['grade'] == "10th"].groupby('school_name')["reading_score"].mean()
junior_reading = students_df.loc[students_df['grade'] == "11th"].groupby('school_name')["reading_score"].mean()
senior_reading = students_df.loc[students_df['grade'] == "12th"].groupby('school_name')["reading_score"].mean()

reading_scores_grade = pd.DataFrame({"9th": freshman_reading,
                                  "10th": sophomore_reading,
                                  "11th": junior_reading,
                                  "12th": senior_reading
})

reading_scores_grade = reading_scores_grade[['9th', '10th', '11th', '12th']]
reading_scores_grade.index.name = "School"

reading_scores_grade
# Out:
#                              9th       10th       11th       12th
# School
# Bailey High School     81.303155  80.907183  80.945643  80.912451
# Cabrera High School    83.676136  84.253219  83.788382  84.287958
# Figueroa High School   81.198598  81.408912  80.640339  81.384863
# Ford High School       80.632653  81.262712  80.403642  80.662338
# Griffin High School    83.369193  83.706897  84.288089  84.013699
# Hernandez High School  80.866860  80.660147  81.396140  80.857143
# Holden High School     83.677165  83.324561  83.815534  84.698795
# Huang High School      81.290284  81.512386  81.417476  80.305983
# Johnson High School    81.260714  80.773431  80.616027  81.227564
# Pena High School       83.807273  83.612000  84.335938  84.591160
# Rodriguez High School  80.993127  80.629808  80.864811  80.376426
# Shelton High School    84.122642  83.441964  84.373786  82.781671
# Thomas High School     83.728850  84.254157  83.585542  83.831361
# ...

# %%
# Scores Based on Per Student Spending Ranges

# Create bins for table
bins = [0, 584.99, 629.99, 644.99, 675]
spending_ranges = ["< $585", "$585 - 629", "$630 - 644", "> $645"]
merge_df['Spending_Bins'] = pd.cut(merge_df['budget']/merge_df['size'], bins, labels = spending_ranges)

by_spending_student = merge_df.groupby('spend_ranges')

# Requested Calculations
avg_math_spending = round(by_spending_student['math_score'].mean(), 2)
avg_reading_spending = round(by_spending_student['reading_score'].mean(), 2)
pass_math_spending = round(merge_df[merge_df['math_score'] >69].groupby('Spending_Bins')["Student ID"].count()/by_spending_student["Student ID"].count()*100,2)
pass_reading_spending = round(merge_df[merge_df['reading_score'] >69].groupby('Spending_Bins')["Student ID"].count()/by_spending_student["Student ID"].count()*100,2)
overall_pass_spending = round(merge_df[(merge_df['reading_score'] >69) & (merge_df['math_score'] >69)].groupby('Spending_Bins')['Student ID'].count()/by_spending_student['Student ID'].count()*100,2)                                                                 

# Dataframe
spending_scores = pd.DataFrame({"Average Math Score": avg_math_spending,
                                "Average Reading Score": avg_reading_spending,
                                "% Passing Math": pass_math_spending,
                                "% Passing Reading": pass_reading_spending,
                                "Overall Passing Rate": overall_pass_spending
})

spending_scores.index.name = "Spending Ranges (Per Student)"
spending_scores = spending_scores.reindex(spending_ranges)

spending_scores
# Out:
#                                Average Math Score  Average Reading Score  \
# Spending Ranges (Per Student)
# < $585                                      83.36                  83.96
# $585 - 629                                  79.98                  82.31
# $630 - 644                                  77.82                  81.30
# > $645                                      77.05                  81.01
#
#                                % Passing Math  % Passing Reading  \
# Spending Ranges (Per Student)
# < $585                                  93.70              96.69
# $585 - 629                              79.11              88.51
# $630 - 644                              70.62              82.60
# > $645                                  66.23              81.11
#
#                                Overall Passing Rate
# Spending Ranges (Per Student)
# < $585                                        90.64
# $585 - 629                                    70.94
# ...

# %%
# Scores Based on School Size

# Create bins for table
bins = [0, 999.99, 1999.99, 5000]
size_ranges = ["Small (< 1,000)", "Medium (1,000-2,000)", "Large (2,000-5,000)"]
merge_df['school_size'] = pd.cut(merge_df['size']/merge_df['size'], bins, labels = size_ranges)

by_school_size = merge_df.groupby('school_size')

# Requested Calculations
avg_math_size = round(by_school_size['math_score'].mean(), 2)
avg_reading_size = round(by_school_size['reading_score'].mean(), 2)
pass_math_size = round(merge_df[merge_df['math_score'] >69].groupby('school_size')["Student ID"].count()/by_school_size["Student ID"].count()*100,2)
pass_reading_size = round(merge_df[merge_df['reading_score'] >69].groupby('school_size')["Student ID"].count()/by_school_size["Student ID"].count()*100,2)
overall_pass_size = round(merge_df[(merge_df['reading_score'] >69) & (merge_df['math_score'] >69)].groupby('school_size')['Student ID'].count()/by_school_size['Student ID'].count()*100,2)                                                                 

# Dataframe
size_scores = pd.DataFrame({"Average Math Score": avg_math_size,
                            "Average Reading Score": avg_reading_size,
                            "% Passing Math": pass_math_size,
                            "% Passing Reading": pass_reading_size,
                            "Overall Passing Rate": overall_pass_size
})

size_scores.index.name = "School Size"
size_scores = size_scores.reindex(size_ranges)

size_scores
# Out:
#                       Average Math Score  Average Reading Score  \
# School Size
# Small (< 1,000)                    78.99                  81.88
# Medium (1,000-2,000)                 NaN                    NaN
# Large (2,000-5,000)                  NaN                    NaN
#
#                       % Passing Math  % Passing Reading  Overall Passing Rate
# School Size
# Small (< 1,000)                74.98              85.81                 65.17
# Medium (1,000-2,000)             NaN                NaN                   NaN
# Large (2,000-5,000)              NaN                NaN                   NaN

# %%
# Scores by School Type

school_type = merge_df.groupby("type")

# Requested calculations
avg_math_type = round(school_type['math_score'].mean(), 2)
avg_reading_type = round(school_type['reading_score'].mean(), 2)
pass_math_type = round(merge_df[merge_df['math_score'] >69].groupby('type')["Student ID"].count()/school_type["Student ID"].count()*100,2)
pass_reading_type = round(merge_df[merge_df['reading_score'] >69].groupby('type')["Student ID"].count()/school_type["Student ID"].count()*100,2)
overall_pass_type = round(merge_df[(merge_df['reading_score'] >69) & (merge_df['math_score'] >69)].groupby('type')['Student ID'].count()/school_type['Student ID'].count()*100,2)                                                                 

# Dataframe
type_scores = pd.DataFrame({"Average Math Score": avg_math_type,
                            "Average Reading Score": avg_reading_type,
                            "% Passing Math": pass_math_type,
                            "% Passing Reading": pass_reading_type,
                            "Overall Passing Rate": overall_pass_type
})

type_scores.index.name = "School Type"

type_scores
# Out:
#              Average Math Score  Average Reading Score  % Passing Math  \
# School Type
# Charter                   83.41                  83.90           93.70
# District                  76.99                  80.96           66.52
#
#              % Passing Reading  Overall Passing Rate
# School Type
# Charter                  96.65                 90.56
# District                 80.91                 53.70
